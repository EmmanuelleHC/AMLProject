# %%
from kafka3 import KafkaConsumer
from json import loads
import pandas as pd

hostip = "192.168.1.111"

def consume_messages(consumer_instance, topic_name):
    try:
        consumer_instance.subscribe([topic_name])

        for message in consumer_instance:
            if message is not None:
                records = message.value
                print("Received records:")
                print_data(records)
                preprocess_and_save(records)

    except Exception as ex:
        print('Exception in consuming messages.')
        print(str(ex))

def preprocess_and_save(data):
    if not isinstance(data, list) or not all(isinstance(record, dict) for record in data):
        print("Invalid data format. Expecting a list of dictionaries.")
        return

    df = pd.DataFrame(data)

    df.to_parquet('parquet/preprocessed_data.parquet', index=False)
    print("Preprocessed data saved to 'preprocessed_data.parquet'\n")

def print_data(data):
    print("Data:")
    for record in data:
        for key, value in record.items():
            print(f"{key}: {value}")
        print("\n")

def connect_kafka_consumer():
    _consumer = None
    try:
        _consumer = KafkaConsumer(
            bootstrap_servers=[f'{hostip}:9092'],
            auto_offset_reset='earliest',
            enable_auto_commit=True,
            group_id='my-group',
            value_deserializer=lambda x: loads(x),
            api_version=(0, 10)
        )
    except Exception as ex:
        print('Exception while connecting Kafka consumer.')
        print(str(ex))
    finally:
        return _consumer

if __name__ == '__main__':
    topic = 'Transaction'
    print('Consuming records..')
    consumer = connect_kafka_consumer()

    if consumer is None:
        print('Exiting script due to connection error.')
        exit()

    consume_messages(consumer, topic)
# Out:
# Consuming records..
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
#
# Received records
# Preprocessed data saved to 'parquet/preprocessed_data.parquet'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      61     print('Exiting script due to connection error.')
#      62     exit()
# ---> 64 consume_messages(consumer, topic)
#
# Cell In[1], line 11, in consume_messages(consumer_instance, topic_name)
#       8 try:
#       9     consumer_instance.subscribe([topic_name])
# ---> 11     for message in consumer_instance:
#      12         if message is not None:
#      13             records = message.value
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/consumer/group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/consumer/group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/consumer/group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/consumer/group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/consumer/group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.10/site-packages/kafka3/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
